# %%
# %run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Data set size: 20936
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (NVIDIA Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 43, 158, 24)       1824
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 43, 158, 24)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 77, 36)        21636
# _________________________________________________________________
# ...

# %%
# from theano.tensor import mean, var
# def normalize_image1(img):
#     """
#     Normalizes an image
#     """
#     _mean = mean(img)
#     _var = var(img)
#     return (img - _mean)/_var

# %%
# %run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Data set size: 21007
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 86, 316, 6)        456
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 86, 316, 6)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import os
# %matplotlib inline
import numpy as np
from sklearn.utils import shuffle
# import csv
# import cv2
# import zipfile
import random
import helper
# Out:
# Using Theano backend.

# %%
data_set_log = helper.load_data_set_log('./data/driving_log.csv', dropping = True)
root = '.'

for idx in range(10):
    _probability = random.uniform(0.0, 1.0)

    if(_probability >= 0.00 and _probability < 0.50):# Images for center camera
        print(data_set_log.center[idx])
    elif(_probability >= 0.50 and _probability < 0.75):# Images for left camera
        print(data_set_log.left[idx])
    elif(_probability >= 0.75):# Images for right camera
        print(data_set_log.right[idx])
# Out:
# IMG/center_2018_01_10_16_58_11_645.jpg
# IMG/right_2018_01_10_16_58_11_715.jpg
# IMG/center_2018_01_10_16_58_11_783.jpg
# IMG/center_2018_01_10_16_58_11_851.jpg
# IMG/center_2018_01_10_16_58_11_919.jpg
# IMG/center_2018_01_10_16_58_11_987.jpg
# IMG/center_2018_01_10_16_58_12_055.jpg
# IMG/left_2018_01_10_16_58_12_123.jpg
# IMG/center_2018_01_10_16_58_13_074.jpg
# IMG/right_2018_01_10_16_58_13_278.jpg

# %%
df = helper.read_csv_df(path='./data/driving_log.csv')
helper.plot_data_dist(
    df.steering, 
    bins=50,
    labelx ='Steering Angle', 
    save=False, 
    save_path='./res/steering_data_distribution.png')
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_dropped = helper.drop(df)
helper.plot_data_dist(
    df_dropped.steering, 
    bins=50,
    labelx ='Steering Angle', 
    save=False, 
    save_path='./res/processed_steering_data_distribution.png')
# Out:
# <class 'pandas.core.series.Series'>

# %%
# %run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Data set size: 71874
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 86, 316, 6)        456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 154, 6)        906
# _________________________________________________________________
# ...

# %%
# %run model.py
# Out:
# >> Loading data set...
# >> Done...
# >> Data set size: 23806
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_3 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_3 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 86, 316, 6)        456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 39, 154, 6)        906
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 77, 6)         0
# ...

# %%
# %run model.py
# Out:
# >> Loading data set...
# >> Done...
# >> Data set size: 23806
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_3 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_3 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 86, 316, 6)        456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 39, 154, 6)        906
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 77, 6)         0
# ...

# %%
# %run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Data set size: 47704
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (NVIDIA Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 43, 158, 24)       1824
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 77, 36)        21636
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 37, 48)         43248
# _________________________________________________________________
# ...

# %%
# %run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Data set size: 41559
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (NVIDIA Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 43, 158, 24)       1824
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 77, 36)        21636
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 37, 48)         43248
# _________________________________________________________________
# ...

# %%
# %run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Image shape: (160, 320, 3)
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 86, 316, 6)        456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 154, 6)        906
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 77, 6)         0
# ...

# %%
# %run model.py
# Out:
# >> Loading data set...
# >> Done...
# >> Image shape: (160, 320, 3)
# >> Build models...
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 86, 316, 6)        456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 154, 6)        906
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 77, 6)         0
# ...

# %%
# %run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Image shape: (160, 320, 3)
# >> Build models...
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 86, 316, 6)        456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 154, 6)        906
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 77, 6)         0
# ...

# %%
#%run model.py
# Out:
# Using Theano backend.
# >> Loading data set...
# >> Done...
# >> Image shape: (160, 320, 3)
# >> Build models...
#
#
#
# >> Building the model (LeNet Architecture)...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 86, 316, 6)        456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 158, 6)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 154, 6)        906
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 77, 6)         0
# ...

# %%
# # Build the models
# print('>> Build models...')
# #lenet = helper.lenet_model(input_shape=input_shape)
# #nvidia = helper.nvidia_model(input_shape=input_shape)
# # Select model
# idx = 0
# model = \
#     helper.lenet_model(input_shape=input_shape) if idx==0 \
#     else helper.nvidia_model(input_shape=input_shape)
# model_names = ['lenet_model', 'nvidia_model']
# model_name = model_names[idx]
# print('\n\n ')
# print('+-------------------------------------------------+')
# print('|                   {0:12s}                  |'.format(model_name))
# print('+-------------------------------------------------+')


# # Train and save the model
# history_object = helper.train_model(
#     model, model_name, X_train, y_train, 
#     loss='mse', optimizer='adam', 
#     valid_split=0.2, epochs = 7)


# # Produce and save visualization    
# helper.produce_visualization(history_object, model_name)
    
    
# Build the models
print('>> Build models...')
lenet = helper.lenet_model(input_shape=input_shape)
nvidia = helper.nvidia_model(input_shape=input_shape)
models = [lenet, nvidia]
model_names = ['lenet_model', 'nvidia_model']


# for model, model_name in zip(models, model_names):
#     print('\n\n ')
#     print('+-------------------------------------------------+')
#     print('|                   {0:12s}                  |'.format(model_name))
#     print('+-------------------------------------------------+')
#     # Train and save the model
#     history_object = helper.train_model(
#                         model, model_name, X_train, y_train, 
#                         loss='mse', optimizer='adam', 
#                         valid_split=0.2, epochs = 7)

#     # Produce and save visualization    
#     helper.produce_visualization(history_object, model_name)

# %%
import helper
helper.unzip('./data.zip')
